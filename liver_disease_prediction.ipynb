# %% [markdown]
# # Exploring Liver Disease with Machine Learning

# %% [markdown]
# # I) Lets look out the Data

# %%
# Import the data processing and visualization libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df_liver = pd.read_csv('indian_liver_patient.csv')

# %%
# Access the first 5 rows of df_liver
df_liver.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %% [markdown]
# # II) Cleaning the data

# %% [markdown]
# # a) Dealing with missing values

# %%
# Define a function that allows us to create a table of missing values in df_liver and their percentages in 
# descending order
def missing_values(data):
    total = data.isnull().sum().sort_values(ascending=False)
    percentage = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
    percentage_final = (round(percentage, 2) * 100)
    total_percent = pd.concat(objs=[total, percentage_final], axis = 1, keys=['Total', '%'])
    return total_percent

# %%
# Find the total count and % of missing values 
missing_values(df_liver)
# Out:
#                             Total    %
# Albumin_and_Globulin_Ratio      4  1.0
# Age                             0  0.0
# Gender                          0  0.0
# Total_Bilirubin                 0  0.0
# Direct_Bilirubin                0  0.0
# Alkaline_Phosphotase            0  0.0
# Alamine_Aminotransferase        0  0.0
# Aspartate_Aminotransferase      0  0.0
# Total_Protiens                  0  0.0
# Albumin                         0  0.0
# Dataset                         0  0.0

# %%
# Replace missing values with the mean of feature column Albumin_and_Globulin_Ratio, 
# then check to see that it has been successfull, where the sum of missig values should be 0
df_liver['Albumin_and_Globulin_Ratio'].fillna(df_liver['Albumin_and_Globulin_Ratio'].mean(), inplace = True)
df_liver['Albumin_and_Globulin_Ratio'].isnull().sum()
# Out:
# 0

# %%
# Repeat to see what is the % of missing values
missing_values(df_liver)
# Out:
#                             Total    %
# Age                             0  0.0
# Gender                          0  0.0
# Total_Bilirubin                 0  0.0
# Direct_Bilirubin                0  0.0
# Alkaline_Phosphotase            0  0.0
# Alamine_Aminotransferase        0  0.0
# Aspartate_Aminotransferase      0  0.0
# Total_Protiens                  0  0.0
# Albumin                         0  0.0
# Albumin_and_Globulin_Ratio      0  0.0
# Dataset                         0  0.0

# %% [markdown]
# # b) Exploring the data visually

# %%
df_liver.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ca09c_row0_col0, #T_ca09c_row1_col1, #T_ca09c_row2_col2, #T_ca09c_row3_col3, #T_ca09c_row4_col4, #T_ca09c_row5_col5, #T_ca09c_row6_col6, #T_ca09c_row7_col7, #T_ca09c_row8_col8, #T_ca09c_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ca09c_row0_col1, #T_ca09c_row5_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ca09c_row0_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_ca09c_row0_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_ca09c_row0_col4, #T_ca09c_row4_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ca09c_row0_col5, #T_ca09c_row7_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ca09c_row0_col6, #T_ca09c_row0_col7, #T_ca09c_row2_col9, #T_ca09c_row3_col8, #T_ca09c_row7_col0, #T_ca09c_row7_col1, #T_ca09c_row8_col3, #T_ca09c_row9_col1, #T_ca09c_row9_col2, #T_ca09c_row9_col4, #T_ca09c_row9_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ca09c_row0_col8, #T_ca09c_row7_col2, #T_ca09c_row8_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ca09c_row0_col9 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_ca09c_row1_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_ca09c_row1_col2 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_ca09c_row1_col3, #T_ca09c_row2_col5, #T_ca09c_row4_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_ca09c_row1_col4, #T_ca09c_row5_col3, #T_ca09c_row7_col9, #T_ca09c_row8_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_ca09c_row1_col5, #T_ca09c_row9_col7 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_ca09c_row1_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_ca09c_row1_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_ca09c_row1_col8, #T_ca09c_row1_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_ca09c_row2_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ca09c_row2_col1 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_ca09c_row2_col3, #T_ca09c_row6_col8 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ca09c_row2_col4 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_ca09c_row2_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ca09c_row2_col7, #T_ca09c_row2_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_ca09c_row3_col0, #T_ca09c_row3_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_ca09c_row3_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_ca09c_row3_col2, #T_ca09c_row4_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_ca09c_row3_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_ca09c_row3_col6, #T_ca09c_row5_col6, #T_ca09c_row5_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ca09c_row3_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_ca09c_row3_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ca09c_row4_col0, #T_ca09c_row5_col7 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_ca09c_row4_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ca09c_row4_col5, #T_ca09c_row7_col6 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_ca09c_row4_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_ca09c_row4_col7, #T_ca09c_row9_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_ca09c_row4_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_ca09c_row5_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ca09c_row5_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_ca09c_row5_col4 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_ca09c_row5_col9 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_ca09c_row6_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ca09c_row6_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ca09c_row6_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_ca09c_row6_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ca09c_row6_col4, #T_ca09c_row9_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_ca09c_row6_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_ca09c_row6_col7 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_ca09c_row6_col9 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_ca09c_row7_col3, #T_ca09c_row7_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ca09c_row7_col8 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_ca09c_row8_col0, #T_ca09c_row9_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ca09c_row8_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ca09c_row8_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_ca09c_row8_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_ca09c_row8_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_ca09c_row8_col7 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_ca09c_row9_col8 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# </style>
# <table id="T_ca09c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca09c_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_ca09c_level0_col1" class="col_heading level0 col1" >Total_Bilirubin</th>
#       <th id="T_ca09c_level0_col2" class="col_heading level0 col2" >Direct_Bilirubin</th>
#       <th id="T_ca09c_level0_col3" class="col_heading level0 col3" >Alkaline_Phosphotase</th>
#       <th id="T_ca09c_level0_col4" class="col_heading level0 col4" >Alamine_Aminotransferase</th>
#       <th id="T_ca09c_level0_col5" class="col_heading level0 col5" >Aspartate_Aminotransferase</th>
#       <th id="T_ca09c_level0_col6" class="col_heading level0 col6" >Total_Protiens</th>
#       <th id="T_ca09c_level0_col7" class="col_heading level0 col7" >Albumin</th>
#       <th id="T_ca09c_level0_col8" class="col_heading level0 col8" >Albumin_and_Globulin_Ratio</th>
#       <th id="T_ca09c_level0_col9" class="col_heading level0 col9" >Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca09c_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_ca09c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ca09c_row0_col1" class="data row0 col1" >0.011763</td>
#       <td id="T_ca09c_row0_col2" class="data row0 col2" >0.007529</td>
#       <td id="T_ca09c_row0_col3" class="data row0 col3" >0.080425</td>
#       <td id="T_ca09c_row0_col4" class="data row0 col4" >-0.086883</td>
#       <td id="T_ca09c_row0_col5" class="data row0 col5" >-0.019910</td>
#       <td id="T_ca09c_row0_col6" class="data row0 col6" >-0.187461</td>
#       <td id="T_ca09c_row0_col7" class="data row0 col7" >-0.265924</td>
#       <td id="T_ca09c_row0_col8" class="data row0 col8" >-0.216089</td>
#       <td id="T_ca09c_row0_col9" class="data row0 col9" >-0.137351</td>
#     </tr>
#     <tr>
#       <th id="T_ca09c_level0_row1" class="row_heading level0 row1" >Total_Bilirubin</th>
#       <td id="T_ca09c_row1_col0" class="data row1 col0" >0.011763</td>
#       <td id="T_ca09c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ca09c_row1_col2" class="data row1 col2" >0.874618</td>
#       <td id="T_ca09c_row1_col3" class="data row1 col3" >0.206669</td>
#       <td id="T_ca09c_row1_col4" class="data row1 col4" >0.214065</td>
#       <td id="T_ca09c_row1_col5" class="data row1 col5" >0.237831</td>
#       <td id="T_ca09c_row1_col6" class="data row1 col6" >-0.008099</td>
#       <td id="T_ca09c_row1_col7" class="data row1 col7" >-0.222250</td>
#       <td id="T_ca09c_row1_col8" class="data row1 col8" >-0.206159</td>
#       <td id="T_ca09c_row1_col9" class="data row1 col9" >-0.220208</td>
#     </tr>
#     <tr>
#       <th id="T_ca09c_level0_row2" class="row_heading level0 row2" >Direct_Bilirubin</th>
#       <td id="T_ca09c_row2_col0" class="data row2 col0" >0.007529</td>
#       <td id="T_ca09c_row2_col1" class="data row2 col1" >0.874618</td>
#       <td id="T_ca09c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ca09c_row2_col3" class="data row2 col3" >0.234939</td>
#       <td id="T_ca09c_row2_col4" class="data row2 col4" >0.233894</td

# %% [markdown]
# The above correlation heatmap demonstrates strong positive (closer to 1) and negative correlations (closer to -1) but also weak positive and negative correlations (closer to zero).

# %% [markdown]
# Based on the correlative pair plots, we find some interesting results directly.
#
# -Positive correlations:
#
# Total Bilirubin and Direct Bilirubin (vice-versa)
#
# Alamine Aminotransferase and Aspartate Aminotransferase (vice-versa)
#
# Total Protein and Albumin (vice-versa)
#
# Albumin and Globulin Ratio and Albumin (vice-versa)
#
# Total Protein and Albumin and Globulin Ration (vice-versa)
#
# -Negative correlations:
#
# Total Protein and age (vice-versa)
#
# Albumin and age (vice-versa)
#
# Albumin and Globulin Ration and age (vice-versa)

# %%
# Change the current categorical feature Gender to a numerical feature of 0 or 1 

df_liver['Gender'] = df_liver['Gender'].apply(lambda x:1 if x == 'Male' else 0)
df_liver.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       0              0.7               0.1                   187
# 1   62       1             10.9               5.5                   699
# 2   62       1              7.3               4.1                   490
# 3   58       1              1.0               0.4                   182
# 4   72       1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %%
# Create a table for Dataset (with and without liver disease) and gender
df_liver_Gender = round(df_liver[['Gender', 'Dataset']].groupby(['Gender'], as_index=False).agg(np.sum), 3)

# Generate plot to determine the effect of gender on the dataset 
plt.figure(figsize=(10,5))

sns.barplot(x="Gender", y="Dataset", data=df_liver_Gender, ci=None)
plt.title("Survival wrt Gender")
plt.ylim(0, 700)
# Out:
# <ipython-input-10-e5d15519d40e>:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Gender", y="Dataset", data=df_liver_Gender, ci=None)
# (0.0, 700.0)

# %% [markdown]
# It appears from these plots that men normally have high liver function test results and hence are likely to have liver disease. This is likely because culturally men in NE of Andhra Pradesh in India consume alchohol more than women. Let us now look a dsitribution plot for all the liver function tests in relation to the target feature and gender.

# %% [markdown]
# #  Applying machine learning approaches to liver disease

# %% [markdown]
# I will employ the following supervised  machine learning models, whilst evaluating the mean accuracy of each of them by a stratified kfold cross validation procedure.

# %%
# Machine learning libraries in sklearn

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score

from sklearn.model_selection import StratifiedKFold, train_test_split, cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
K_fold = StratifiedKFold(n_splits=10)

# %%
# Separate train features and response
X = df_liver.drop(["Dataset"],axis = 1)
Y = df_liver["Dataset"]



# Scale the data
scaler=MinMaxScaler()
scaled_values=scaler.fit_transform(X)
X.loc[:,:]=scaled_values

# Create the Train and Test sets
# Splitting the train and test into 70% training and 30% testing
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,stratify=Y, test_size=0.3,random_state=42)


# Find the shape of all sets
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((408, 10), (408,), (175, 10), (175,))

# %% [markdown]
# ##### Logistic regression

# %% [markdown]
# Logistic regression models the probabilities for classification problems with two possible outcomes. Furthermore, this models is an extension of the linear regression model but for classification problems.

# %%
# Logistic Regression
model_logreg = LogisticRegression()
model_logreg.fit(X_train,Y_train)
y_pred = model_logreg.predict(X_test)

scores = cross_val_score(model_logreg, X_train, Y_train, cv=K_fold, n_jobs=4, scoring='accuracy')

print(scores)
score_logreg = round(np.mean(scores) * 100, 3)
print("Score: {}".format(score_logreg))
acc_logreg = round(np.mean(accuracy_score(Y_test, y_pred)) * 100, 3)
print("Accuracy: {}".format(acc_logreg))
# Out:
# [0.73170732 0.73170732 0.70731707 0.68292683 0.70731707 0.68292683
#  0.70731707 0.73170732 0.725      0.725     ]
# Score: 71.329
# Accuracy: 72.0

# %% [markdown]
# ##### KNeighborsClassifier

# %% [markdown]
# This is a  test that searches for the K nearest measurements of the training data and draws a Euclidean distance. It then votes based on that information of how to classify the data.

# %%
# K-Neighbors 
model_knn = KNeighborsClassifier(n_neighbors=5)
model_knn.fit(X_train, Y_train)
y_pred = model_knn.predict(X_test)

scores = cross_val_score(model_knn, X_train, Y_train, cv=K_fold, n_jobs=4, scoring='accuracy')

print(scores)
score_knn = round(np.mean(scores) * 100, 3)
print("Score: {}".format(score_knn))
acc_knn = round(np.mean(accuracy_score(Y_test, y_pred)) * 100, 3)
print("Accuracy: {}".format(acc_knn))
# Out:
# [0.73170732 0.70731707 0.70731707 0.58536585 0.56097561 0.75609756
#  0.63414634 0.70731707 0.725      0.6       ]
# Score: 67.152
# Accuracy: 65.143

# %% [markdown]
# ##### Decision Tree Classifier

# %% [markdown]
# The data is continously split according to a certain parameter, in this case we are basing it on the features.

# %%
# Decision Tree 
model_dtc = DecisionTreeClassifier()
model_dtc.fit(X_train, Y_train)
y_pred = model_dtc.predict(X_test)

scores = cross_val_score(model_dtc, X_train, Y_train, cv=K_fold, n_jobs=4, scoring='accuracy')

print(scores)
score_dtc = round(np.mean(scores) * 100, 3)
print("Score: {}".format(score_dtc))
acc_dtc = round(np.mean(accuracy_score(Y_test, y_pred)) * 100, 3)
print("Accuracy: {}".format(acc_dtc))
# Out:
# [0.68292683 0.68292683 0.70731707 0.70731707 0.68292683 0.53658537
#  0.70731707 0.6097561  0.6        0.625     ]
# Score: 65.421
# Accuracy: 64.0

# %% [markdown]
# ##### Random Forest Classifier

# %% [markdown]
# Random forest classifier creates decision trees on randomly selected data samples. The model obtains prediction from each tree and subsequently selects the best solution by means of voting. Furthermore, random forest classfier also provides a very good indicator of the feature importance.

# %%
# Random Forest 
model_rfc = RandomForestClassifier(n_estimators=50)
model_rfc.fit(X_train, Y_train)
y_pred = model_rfc.predict(X_test)

scores = cross_val_score(model_rfc, X_train, Y_train, cv=K_fold, n_jobs=4, scoring ='accuracy')

print(scores)
score_rfc = round(np.mean(scores) * 100, 3)
print("Score: {}".format(score_rfc))
acc_rfc = round(np.mean(accuracy_score(Y_test, y_pred)) * 100, 3)
print("Accuracy: {}".format(acc_rfc))
# Out:
# [0.65853659 0.80487805 0.73170732 0.75609756 0.73170732 0.63414634
#  0.82926829 0.68292683 0.7        0.7       ]
# Score: 72.293
# Accuracy: 69.714

# %% [markdown]
# ##### Which is the best model?

# %%
results = pd.DataFrame({'Model': ['Logistic Regression','KNeighbor', 
                                  'Decision Tree ', 'Random Forest ', 
                                  ],
                        'Accuracy': [acc_logreg, acc_knn,  acc_dtc, acc_rfc, 
                                  ], 
                        'Score': [score_logreg, score_knn, score_dtc, score_rfc,  
                              ],})
df_results = results.sort_values(by='Score', ascending=False)
df_results = df_results.set_index('Score')
df_results
# Out:
#                       Model  Accuracy
# Score
# 72.293       Random Forest     69.714
# 71.329  Logistic Regression    72.000
# 67.152            KNeighbor    65.143
# 65.421       Decision Tree     64.000
